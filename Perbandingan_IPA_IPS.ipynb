# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
ips = pd.read_excel('/content/drive/My Drive/IFEST/PAKET C/IPS/CAPAIAN NILAI UJIAN NASIONAL PAKETC TAHUN AJARAN 2018-2019_ .xlsx')
ipa= pd.read_excel('/content/drive/My Drive/IFEST/PAKET C/PaketC 2018-2019.xlsx')

# %%
ips.rename(columns={'Unnamed: 1':'KODE', 'Unnamed: 2':'NAMA PROVINSI', 'Unnamed: 3':'JUMLAH SATUAN PENDIDIKAN', 'Unnamed: 4':'JUMLAH PESERTA', 'Unnamed: 5':'BAHASA INDONESIA', 'Unnamed: 6':'BAHASA INGGRIS', 'Unnamed: 7':'MATEMATIKA', 'Unnamed: 8':'EKONOMI','Unnamed: 9':'SOSIOLOGI', 'Unnamed: 10':'GEOGRAFI', 'Unnamed: 11':'PKN','Unnamed: 12':'RERATA NILAI'},inplace=True )
ipa.rename(columns={'Unnamed: 1':'KODE', 'Unnamed: 2':'NAMA PROVINSI', 'Unnamed: 3':'JUMLAH SATUAN PENDIDIKAN', 'Unnamed: 4':'JUMLAH PESERTA', 'Unnamed: 5':'BAHASA INDONESIA', 'Unnamed: 6':'BAHASA INGGRIS', 'Unnamed: 7':'MATEMATIKA', 'Unnamed: 8':'FISIKA','Unnamed: 9':'KIMIA', 'Unnamed: 10':'BIOLOGI', 'Unnamed: 11':'PKN','Unnamed: 12':'RERATA NILAI'},inplace=True )

# %%
ipacopy=ipa.copy()
ipacopy.dropna(inplace = True)
ipacopy=ipacopy.drop(['CAPAIAN NILAI UJIAN NASIONAL'],axis=1)

ipscopy=ips.copy()
ipscopy.dropna(inplace = True)
ipscopy=ipscopy.drop(['CAPAIAN NILAI UJIAN NASIONAL'],axis=1)

# %%
ipa.dropna(inplace = True)
ipa=ipa.drop(['CAPAIAN NILAI UJIAN NASIONAL'],axis=1)

ips.dropna(inplace = True)
ips=ips.drop(['CAPAIAN NILAI UJIAN NASIONAL'],axis=1)

# %%
plt.figure(figsize=(8,9))
print('Jumlah Peserta IPA')
ax=sns.barplot(x='JUMLAH PESERTA', y='NAMA PROVINSI', data = ipacopy.sort_values('JUMLAH PESERTA',ascending=False),palette="cool")
ax.set_xlabel('JUMLAH PESERTA')
# Out:
# Jumlah Peserta IPA
# Text(0.5, 0, 'JUMLAH PESERTA')

# %%
plt.figure(figsize=(8,9))
print('Jumlah Peserta IPS')
ax=sns.barplot(x='JUMLAH PESERTA', y='NAMA PROVINSI', data = ipscopy.sort_values('JUMLAH PESERTA',ascending=False),palette="cool")
ax.set_xlabel('JUMLAH PESERTA')
# Out:
# Jumlah Peserta IPS
# Text(0.5, 0, 'JUMLAH PESERTA')
