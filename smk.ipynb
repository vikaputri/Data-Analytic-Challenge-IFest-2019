# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %% [markdown]
# # **TINGKAT PROVINSI (NASIONAL)**

# %%
df = pd.read_excel('/content/drive/My Drive/DQLAB/NilaiUNSMK2019.xlsx')
dfcop = df.copy()
df2 = pd.read_excel('/content/drive/My Drive/DQLAB/NilaiUNSMK2018.xlsx')
df3 = pd.read_excel('/content/drive/My Drive/DQLAB/NilaiUNSMK2017.xlsx')
df4 = pd.read_excel('/content/drive/My Drive/DQLAB/NilaiUNSMK2016.xlsx')
df5 = pd.read_excel('/content/drive/My Drive/DQLAB/NilaiUNSMK2015.xlsx')

# %%
df.rename(columns={'Unnamed: 1':'KODE', 'Unnamed: 2':'NAMA_PROVINSI', 'Unnamed: 3':'JUMLAH SATUAN PENDIDIKAN', 'Unnamed: 4':'JUMLAH PESERTA', 
                   'Unnamed: 5':'BAHASA INDONESIA', 'Unnamed: 6':'BAHASA INGGRIS', 'Unnamed: 7':'MATEMATIKA', 'Unnamed: 8':'KOMPETENSI','Unnamed: 9':'RERATA NILAI'},inplace=True )
df2.rename(columns={'Unnamed: 1':'KODE', 'Unnamed: 2':'NAMA_PROVINSI', 'Unnamed: 3':'JUMLAH SATUAN PENDIDIKAN', 'Unnamed: 4':'JUMLAH PESERTA', 
                   'Unnamed: 5':'BAHASA INDONESIA', 'Unnamed: 6':'BAHASA INGGRIS', 'Unnamed: 7':'MATEMATIKA', 'Unnamed: 8':'KOMPETENSI','Unnamed: 9':'RERATA NILAI'},inplace=True )
df3.rename(columns={'Unnamed: 1':'KODE', 'Unnamed: 2':'NAMA_PROVINSI', 'Unnamed: 3':'JUMLAH SATUAN PENDIDIKAN', 'Unnamed: 4':'JUMLAH PESERTA', 
                   'Unnamed: 5':'BAHASA INDONESIA', 'Unnamed: 6':'BAHASA INGGRIS', 'Unnamed: 7':'MATEMATIKA', 'Unnamed: 8':'KOMPETENSI','Unnamed: 9':'RERATA NILAI'},inplace=True )
df4.rename(columns={'Unnamed: 1':'KODE', 'Unnamed: 2':'NAMA_PROVINSI', 'Unnamed: 3':'JUMLAH SATUAN PENDIDIKAN', 'Unnamed: 4':'JUMLAH PESERTA', 
                   'Unnamed: 5':'BAHASA INDONESIA', 'Unnamed: 6':'BAHASA INGGRIS', 'Unnamed: 7':'MATEMATIKA', 'Unnamed: 8':'KOMPETENSI','Unnamed: 9':'RERATA NILAI'},inplace=True )
df5.rename(columns={'Unnamed: 1':'KODE', 'Unnamed: 2':'NAMA_PROVINSI', 'Unnamed: 3':'JUMLAH SATUAN PENDIDIKAN', 'Unnamed: 4':'JUMLAH PESERTA', 
                   'Unnamed: 5':'BAHASA INDONESIA', 'Unnamed: 6':'BAHASA INGGRIS', 'Unnamed: 7':'MATEMATIKA', 'Unnamed: 8':'KOMPETENSI','Unnamed: 9':'RERATA NILAI'},inplace=True )

# %%
import numpy as np
unyear = [df5,df4,df3,df2,df]
year = pd.DataFrame (columns=df.columns)
year.columns = [c.replace(' ', '_') for c in year.columns]
for i in unyear:
    i.columns = [c.replace(' ', '_') for c in i.columns]
    i = i.loc[i.NAMA_PROVINSI == 'NASIONAL'] 
    year=year.append(i)

# %%
year = year.drop(['NAMA_PROVINSI','KODE','CAPAIAN_NILAI_UJIAN_NASIONAL'],axis=1)
year['TAHUN'] = [2015,2016,2017,2018,2019]
year = year.reset_index()
year = year.drop(['index'],axis=1)
dfcop.rename(columns={'Unnamed: 1':'KODE', 'Unnamed: 2':'NAMA_PROVINSI', 'Unnamed: 3':'JUMLAH_SATUAN_PENDIDIKAN', 'Unnamed: 4':'JUMLAH PESERTA', 
                   'Unnamed: 5':'BAHASA INDONESIA', 'Unnamed: 6':'BAHASA INGGRIS', 'Unnamed: 7':'MATEMATIKA','Unnamed: 8':'KOMPETENSI','Unnamed: 9':'RERATA NILAI'},inplace=True )
dfcop.dropna(inplace = True)
dfcop=dfcop.drop(['CAPAIAN NILAI UJIAN NASIONAL'],axis=1)
df.dropna(inplace = True)

# %%
df

# %%
fig,axes = plt.subplots(2,2)
fig.set_size_inches(15, 12)
print('Perubahan Nilai Ujian Nasional Setiap Mata Pelajaran dari Tahun ke Tahun')
sns.catplot(y='BAHASA_INDONESIA', x='TAHUN', data=year, ax=axes[0,0] ,kind = 'point')
sns.catplot(y='BAHASA_INGGRIS', x='TAHUN', data=year, ax=axes[0,1] ,kind = 'point')
sns.catplot(y='MATEMATIKA', x='TAHUN', data=year, ax=axes[1,0] ,kind = 'point')
sns.catplot(y='KOMPETENSI', x='TAHUN', data=year, ax=axes[1,1] ,kind = 'point')
# Out:
# Perubahan Nilai Ujian Nasional Setiap Mata Pelajaran dari Tahun ke Tahun

# %% [markdown]
# **Rerata nilai UN SMK dari tahun 2015 sampai tahun 2019**

# %%
sns.catplot(y='RERATA_NILAI', x='TAHUN', data=year ,kind = 'point')

# %%
sns.catplot(x='TAHUN', y='JUMLAH_PESERTA', data=year, kind='point')
plt.title("JUMLAH_PESERTA UN SMA IPA Tahun 2015-2019")
# Out:
# Text(0.5, 1.0, 'JUMLAH_PESERTA UN SMA IPA Tahun 2015-2019')

# %%
plt.figure(figsize=(8,9))
print('JUMLAH PESERTA UN SMK')
ax=sns.barplot(x='JUMLAH_PESERTA', y='NAMA_PROVINSI', data = df.sort_values('JUMLAH_PESERTA',ascending=False),palette="cool")
ax.set_xlabel('JUMLAH_PESERTA')
# Out:
# JUMLAH PESERTA UN SMK
# Text(0.5, 0, 'JUMLAH_PESERTA')

# %% [markdown]
# **5 Provinsi dengan Nilai UN Tertinggi (Setiap Mapel)**

# %%
df.columns = [c.replace(' ', '_') for c in df.columns]

fig,axes = plt.subplots(2,2)
plt.subplots_adjust(wspace=0.75, hspace=0.3)
fig.set_size_inches(15, 12)
print('5 Provinsi dengan Rata-Rata Nilai UN Tertinggi untuk Setiap Mata Pelajaran')
sns.barplot(x='BAHASA_INDONESIA', y='NAMA_PROVINSI', data=df.sort_values('BAHASA_INDONESIA',ascending = False).head(5),ax=axes[0,0],palette="cool")
sns.barplot(x='BAHASA_INGGRIS', y='NAMA_PROVINSI', data=df.sort_values('BAHASA_INGGRIS',ascending = False).head(5),ax=axes[0,1],palette="cool")
sns.barplot(x='MATEMATIKA', y='NAMA_PROVINSI', data=df.sort_values('MATEMATIKA',ascending = False).head(5),ax=axes[1,0],palette="cool")
sns.barplot(x='KOMPETENSI', y='NAMA_PROVINSI', data=df.sort_values('KOMPETENSI',ascending = False).head(5),ax=axes[1,1],palette="cool")
# Out:
# 5 Provinsi dengan Rata-Rata Nilai UN Tertinggi untuk Setiap Mata Pelajaran

# %% [markdown]
# **5 Provinsi dengan Nilai UN Terendah (Setiap Mapel)**

# %%
fig,axes = plt.subplots(2,2)
plt.subplots_adjust(wspace=0.75, hspace=0.3)
fig.set_size_inches(15,12)
print('5 Provinsi dengan Nilai UN Terendah untuk Setiap Mata Pelajaran')
sns.barplot(x='BAHASA_INDONESIA', y='NAMA_PROVINSI', data=df.sort_values('BAHASA_INDONESIA',ascending = False).tail(5),ax=axes[0,0],palette="OrRd")
sns.barplot(x='BAHASA_INGGRIS', y='NAMA_PROVINSI', data=df.sort_values('BAHASA_INGGRIS',ascending = False).tail(5),ax=axes[0,1],palette="OrRd")
sns.barplot(x='MATEMATIKA', y='NAMA_PROVINSI', data=df.sort_values('MATEMATIKA',ascending = False).tail(5),ax=axes[1,0],palette="OrRd")
sns.barplot(x='KOMPETENSI', y='NAMA_PROVINSI', data=df.sort_values('KOMPETENSI',ascending = False).tail(5),ax=axes[1,1],palette="OrRd")
# Out:
# 5 Provinsi dengan Nilai UN Terendah untuk Setiap Mata Pelajaran

# %% [markdown]
# **Rerata tertinggi UN SMK**

# %%
df1=df.copy()
df1 = df1.stack().str.replace(',','.').unstack()
df1[['RERATA_NILAI']] = df1[['RERATA_NILAI']].apply(pd.to_numeric)

# %%
fig,axes = plt.subplots(2)
plt.subplots_adjust(wspace=0.75, hspace=0.3)
fig.set_size_inches(8, 7)
print('RERATA TERTINGGI UN SMK')
sns.barplot(x='RERATA_NILAI', y='NAMA_PROVINSI', data=df1.sort_values('RERATA_NILAI',ascending = False).head(5),ax=axes[0],palette="cool")
sns.barplot(x='RERATA_NILAI', y='NAMA_PROVINSI', data=df1.sort_values('RERATA_NILAI',ascending = False).tail(5),ax=axes[1],palette="OrRd")
# Out:
# RERATA TERTINGGI UN SMK

# %% [markdown]
# **Penguasaan 4 mata pelajaran UN SMK di tiap provinsi**

# %%
plt.figure(figsize=(8,15))
sns.barplot(x='BAHASA_INDONESIA', y='NAMA_PROVINSI', data=df.sort_values('BAHASA_INDONESIA',ascending = False),palette="cool",)

# %%
plt.figure(figsize=(8,15))
sns.barplot(x='BAHASA_INGGRIS', y='NAMA_PROVINSI', data=df.sort_values('BAHASA_INGGRIS',ascending = False),palette="cool",)

# %%
plt.figure(figsize=(8,15))
sns.barplot(x='MATEMATIKA', y='NAMA_PROVINSI', data=df.sort_values('MATEMATIKA',ascending = False),palette="cool",)

# %%
plt.figure(figsize=(8,15))
sns.barplot(x='KOMPETENSI', y='NAMA_PROVINSI', data=df.sort_values('KOMPETENSI',ascending = False),palette="cool",)

# %%
plt.figure(figsize=(6,5))
sns.barplot(x='KOMPETENSI', y='NAMA_PROVINSI', data=df.sort_values('KOMPETENSI',ascending = False).tail(5),palette="cool",)

# %% [markdown]
# # **TINGKAT KOTA (KABUPATEN)**

# %%
DKI = pd.read_excel('/content/drive/My Drive/DQLAB/PROVINSI/2019/NilaiUNDKI.xlsx')
DIY = pd.read_excel('/content/drive/My Drive/DQLAB/PROVINSI/2019/NilaiUNYogya.xlsx')
JABAR = pd.read_excel('/content/drive/My Drive/DQLAB/PROVINSI/2019/NilaiUNJabar.xlsx')
JATENG = pd.read_excel('/content/drive/My Drive/DQLAB/PROVINSI/2019/NilaiUNJateng.xlsx')
JATIM = pd.read_excel('/content/drive/My Drive/DQLAB/PROVINSI/2019/NilaiUNJatim.xlsx')
JAMBI = pd.read_excel('/content/drive/My Drive/DQLAB/PROVINSI/2019/NilaiUNJambi.xlsx')
DIY = pd.read_excel('/content/drive/My Drive/DQLAB/PROVINSI/2019/NilaiUNYogya.xlsx')
BANTEN = pd.read_excel('/content/drive/My Drive/DQLAB/PROVINSI/2019/NilaiUNBanten.xlsx')
SUMSEL = pd.read_excel('/content/drive/My Drive/DQLAB/PROVINSI/2019/NilaiUNSumsel.xlsx')
SUMUT = pd.read_excel('/content/drive/My Drive/DQLAB/PROVINSI/2019/NilaiUNSumut.xlsx')
SUMBAR = pd.read_excel('/content/drive/My Drive/DQLAB/PROVINSI/2019/NilaiUNSubar.xlsx')
LAMPUNG = pd.read_excel('/content/drive/My Drive/DQLAB/PROVINSI/2019/NilaiUNLampung.xlsx')
RIAU = pd.read_excel('/content/drive/My Drive/DQLAB/PROVINSI/2019/NilaiUNRiau.xlsx')
KEPRIAU = pd.read_excel('/content/drive/My Drive/DQLAB/PROVINSI/2019/NilaiUNKepRiau.xlsx')
BELITUNG = pd.read_excel('/content/drive/My Drive/DQLAB/PROVINSI/2019/NilaiUNBangkaBelitung.xlsx')
BENGKULU = pd.read_excel('/content/drive/My Drive/DQLAB/PROVINSI/2019/NilaiUNBengkulu.xlsx')
ACEH = pd.read_excel('/content/drive/My Drive/DQLAB/PROVINSI/2019/NilaiUNAceh.xlsx')
KALSEL= pd.read_excel('/content/drive/My Drive/DQLAB/PROVINSI/2019/NilaiUNKalsel.xlsx')
KALBAR = pd.read_excel('/content/drive/My Drive/DQLAB/PROVINSI/2019/NilaiUNKalbar.xlsx')
KALTIM = pd.read_excel('/content/drive/My Drive/DQLAB/PROVINSI/2019/NilaiUNKaltim.xlsx')
KALUT = pd.read_excel('/content/drive/My Drive/DQLAB/PROVINSI/2019/NilaiUNKalut.xlsx')
KALTENG = pd.read_excel('/content/drive/My Drive/DQLAB/PROVINSI/2019/NilaiUNKalteng.xlsx')
SULSEL = pd.read_excel('/content/drive/My Drive/DQLAB/PROVINSI/2019/NilaiUNSulsel.xlsx')
SULUT = pd.read_excel('/content/drive/My Drive/DQLAB/PROVINSI/2019/NilaiUNSulut.xlsx')
SULTENG = pd.read_excel('/content/drive/My Drive/DQLAB/PROVINSI/2019/NilaiUNSulteng.xlsx')
SULBAR= pd.read_excel('/content/drive/My Drive/DQLAB/PROVINSI/2019/NilaiUNSulbar.xlsx')
SULTENGG = pd.read_excel('/content/drive/My Drive/DQLAB/PROVINSI/2019/NilaiUNSultenggara.xlsx')
GORONTALO = pd.read_excel('/content/drive/My Drive/DQLAB/PROVINSI/2019/NilaiUNGorontalo.xlsx')
MALUKU = pd.read_excel('/content/drive/My Drive/DQLAB/PROVINSI/2019/NilaiUNMaluku.xlsx')
MALUKUUT = pd.read_excel('/content/drive/My Drive/DQLAB/PROVINSI/2019/NilaiUNMalukuUtara.xlsx')
NTB = pd.read_excel('/content/drive/My Drive/DQLAB/PROVINSI/2019/NilaiUNNTB.xlsx')
NTT = pd.read_excel('/content/drive/My Drive/DQLAB/PROVINSI/2019/NilaiUNNTT.xlsx')
BALI = pd.read_excel('/content/drive/My Drive/DQLAB/PROVINSI/2019/NilaiUNBali.xlsx')
PAPUA = pd.read_excel('/content/drive/My Drive/DQLAB/PROVINSI/2019/NilaiUNPapua.xlsx')
PAPUABAR = pd.read_excel('/content/drive/My Drive/DQLAB/PROVINSI/2019/NilaiUNPapuaBarat.xlsx')

# %%
provinsi= [DKI,DIY,JAMBI,JABAR,JATENG,JATIM,BANTEN,LAMPUNG,BELITUNG,SUMSEL,RIAU,BENGKULU,SUMUT,SUMBAR,ACEH,KEPRIAU,KALTIM,KALBAR,KALTENG
           ,KALUT,KALSEL,SULSEL,SULUT,SULTENG,SULTENGG,SULBAR,GORONTALO,MALUKU,MALUKUUT,NTB,NTT,BALI,PAPUA,PAPUABAR]
for i in provinsi :
    i.rename(columns={'Unnamed: 1':'KODE', 'Unnamed: 2':'NAMA_KOTA/KABUPATEN', 'Unnamed: 3':'JUMLAH_SATUAN_PENDIDIKAN', 'Unnamed: 4':'JUMLAH_PESERTA', 
                    'Unnamed: 5':'BAHASA_INDONESIA', 'Unnamed: 6':'BAHASA_INGGRIS', 'Unnamed: 7':'MATEMATIKA', 'Unnamed: 8':'KOMPETENSI','Unnamed: 9':'RERATA_NILAI'},inplace=True )  
    i.dropna(inplace = True)
    i.drop(['CAPAIAN NILAI UJIAN NASIONAL'],axis=1)

# %%
kota = pd.concat(provinsi)
kota = kota.drop(['CAPAIAN NILAI UJIAN NASIONAL'],axis=1)
kota = kota.sort_values('KODE',ascending = True)
kota = kota.reset_index()
kota = kota.drop(['index'],axis=1)

# %%
kota.tail()
# Out:
#       KODE    NAMA_KOTA/KABUPATEN  ... KOMPETENSI RERATA_NILAI
# 509   3401     KABUPATEN BULUNGAN  ...      43.62        45,13
# 510   3402           KOTA TARAKAN  ...      44.74        46,95
# 511   3403      KABUPATEN NUNUKAN  ...      44.42        45,42
# 512   3404      KABUPATEN MALINAU  ...      35.17        38,85
# 513   3405  KABUPATEN TANA TIDUNG  ...          -            -
#
# [5 rows x 9 columns]

# %%
kota.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 514 entries, 0 to 513
# Data columns (total 9 columns):
# KODE                        514 non-null object
# NAMA_KOTA/KABUPATEN         514 non-null object
# JUMLAH_SATUAN_PENDIDIKAN    514 non-null object
# JUMLAH_PESERTA              514 non-null object
# BAHASA_INDONESIA            514 non-null object
# BAHASA_INGGRIS              514 non-null object
# MATEMATIKA                  514 non-null object
# KOMPETENSI                  514 non-null object
# RERATA_NILAI                514 non-null object
# dtypes: object(9)
# memory usage: 36.2+ KB

# %%
kota = kota.replace('-','0')
kota[['BAHASA_INDONESIA', 'BAHASA_INGGRIS','MATEMATIKA','KOMPETENSI']] = kota[['BAHASA_INDONESIA', 'BAHASA_INGGRIS','MATEMATIKA','KOMPETENSI']].apply(pd.to_numeric)

# %% [markdown]
# **5 Kota dengan nilai UN SMK Terbaik Tiap Mata Pelajaran**

# %%
fig,axes = plt.subplots(2,2)
plt.subplots_adjust(wspace=0.75, hspace=0.3)
fig.set_size_inches(15, 12)
print('5 Kota dengan UN SMK Teratas')
sns.barplot(x='BAHASA_INDONESIA', y='NAMA_KOTA/KABUPATEN', data=kota.sort_values('BAHASA_INDONESIA',ascending = False).head(5),ax=axes[0,0],palette="cool")
sns.barplot(x='BAHASA_INGGRIS', y='NAMA_KOTA/KABUPATEN', data=kota.sort_values('BAHASA_INGGRIS',ascending = False).head(5),ax=axes[0,1],palette="cool")
sns.barplot(x='MATEMATIKA', y='NAMA_KOTA/KABUPATEN', data=kota.sort_values('MATEMATIKA',ascending = False).head(5),ax=axes[1,0],palette="cool")
sns.barplot(x='KOMPETENSI', y='NAMA_KOTA/KABUPATEN', data=kota.sort_values('KOMPETENSI',ascending = False).head(5),ax=axes[1,1],palette="cool")
# Out:
# 5 Kota dengan UN SMK Teratas

# %%
kota=kota.copy()
kota = kota.stack().str.replace(',','.').unstack()
kota[['RERATA_NILAI']] = kota[['RERATA_NILAI']].apply(pd.to_numeric)
plt.figure(figsize=(6,4))
sns.barplot(x='RERATA_NILAI', y='NAMA_KOTA/KABUPATEN', data=kota.sort_values('RERATA_NILAI',ascending = False).head(5),palette="cool")

# %%
plt.figure(figsize=(6,4))
sns.barplot(x='RERATA_NILAI', y='NAMA_KOTA/KABUPATEN', data=kota.sort_values('RERATA_NILAI',ascending = False).tail(5),palette="cool")

# %%
plt.figure(figsize=(8,15))
ax=sns.barplot(x='BAHASA_INDONESIA', y='NAMA_KOTA/KABUPATEN', data=kota.sort_values('BAHASA_INDONESIA',ascending = False).tail(50),palette="OrRd")

# %%
plt.figure(figsize=(8,15))
ax=sns.barplot(x='BAHASA_INGGRIS', y='NAMA_KOTA/KABUPATEN', data=kota.sort_values('BAHASA_INGGRIS',ascending = False).tail(50),palette="OrRd")

# %%
plt.figure(figsize=(8,15))
ax=sns.barplot(x='MATEMATIKA', y='NAMA_KOTA/KABUPATEN', data=kota.sort_values('MATEMATIKA',ascending = False).tail(50),palette="OrRd")

# %%
plt.figure(figsize=(8,15))
ax=sns.barplot(x='KOMPETENSI', y='NAMA_KOTA/KABUPATEN', data=kota.sort_values('KOMPETENSI',ascending = False).tail(50),palette="OrRd")

# %%
plt.figure(figsize=(8,45))
ax=sns.barplot(x='RERATA_NILAI', y='NAMA_KOTA/KABUPATEN', data=kota.sort_values('RERATA_NILAI',ascending = False).tail(250),palette="OrRd")

# %%
sns.barplot(x='RERATA_NILAI', y='NAMA_KOTA/KABUPATEN', data=kota.sort_values('RERATA_NILAI',ascending = False).head(5),palette="cool")

# %% [markdown]
# # **TINGKAT SEKOLAH**

# %%
DKIs = pd.read_excel('/content/drive/My Drive/DQLAB/SEKOLAH/2019/NilaiUNDKI.xlsx')
DIYs = pd.read_excel('/content/drive/My Drive/DQLAB/SEKOLAH/2019/NilaiUNDIY.xlsx')
JABARs = pd.read_excel('/content/drive/My Drive/DQLAB/SEKOLAH/2019/NilaiUNJabar.xlsx')
JATENGs = pd.read_excel('/content/drive/My Drive/DQLAB/SEKOLAH/2019/NilaiUNJateng.xlsx')
JATIMs = pd.read_excel('/content/drive/My Drive/DQLAB/SEKOLAH/2019/NilaiUNJatim.xlsx')
JAMBIs = pd.read_excel('/content/drive/My Drive/DQLAB/SEKOLAH/2019/NilaiUNJambi.xlsx')
BANTENs = pd.read_excel('/content/drive/My Drive/DQLAB/SEKOLAH/2019/NilaiUNBanten.xlsx')
SUMSELs = pd.read_excel('/content/drive/My Drive/DQLAB/SEKOLAH/2019/NilaiUNSumsel.xlsx')
SUMUTs = pd.read_excel('/content/drive/My Drive/DQLAB/SEKOLAH/2019/NilaiUNSumut.xlsx')
SUMBARs = pd.read_excel('/content/drive/My Drive/DQLAB/SEKOLAH/2019/NilaiUNSumbar.xlsx')
LAMPUNGs = pd.read_excel('/content/drive/My Drive/DQLAB/SEKOLAH/2019/NilaiUNLampung.xlsx')
RIAUs = pd.read_excel('/content/drive/My Drive/DQLAB/SEKOLAH/2019/NilaiUNRiau.xlsx')
KEPRIAUs = pd.read_excel('/content/drive/My Drive/DQLAB/SEKOLAH/2019/NilaiUNKepRiau.xlsx')
BELITUNGs = pd.read_excel('/content/drive/My Drive/DQLAB/SEKOLAH/2019/NilaiUNBangkaBelitung.xlsx')
BENGKULUs = pd.read_excel('/content/drive/My Drive/DQLAB/SEKOLAH/2019/NilaiUNBengkulu.xlsx')
ACEHs = pd.read_excel('/content/drive/My Drive/DQLAB/SEKOLAH/2019/NilaiUNAceh.xlsx')
KALSELs= pd.read_excel('/content/drive/My Drive/DQLAB/SEKOLAH/2019/NilaiUNKalsel.xlsx')
KALBARs = pd.read_excel('/content/drive/My Drive/DQLAB/SEKOLAH/2019/NilaiUNKalbar.xlsx')
KALTIMs = pd.read_excel('/content/drive/My Drive/DQLAB/SEKOLAH/2019/NilaiUNKaltim.xlsx')
KALUTs = pd.read_excel('/content/drive/My Drive/DQLAB/SEKOLAH/2019/NilaiUNKalut.xlsx')
KALTENGs = pd.read_excel('/content/drive/My Drive/DQLAB/SEKOLAH/2019/NilaiUNKalteng.xlsx')
SULSELs = pd.read_excel('/content/drive/My Drive/DQLAB/SEKOLAH/2019/NilaiUNSulsel.xlsx')
SULUTs = pd.read_excel('/content/drive/My Drive/DQLAB/SEKOLAH/2019/NilaiUNSulut.xlsx')
SULTENGs = pd.read_excel('/content/drive/My Drive/DQLAB/SEKOLAH/2019/NilaiUNSulteng.xlsx')
SULBARs= pd.read_excel('/content/drive/My Drive/DQLAB/SEKOLAH/2019/NilaiUNSulbar.xlsx')
SULTENGGs = pd.read_excel('/content/drive/My Drive/DQLAB/SEKOLAH/2019/NilaiUNSultenggara.xlsx')
GORONTALOs = pd.read_excel('/content/drive/My Drive/DQLAB/SEKOLAH/2019/NilaiUNGorontalo.xlsx')
MALUKUs = pd.read_excel('/content/drive/My Drive/DQLAB/SEKOLAH/2019/NilaiUNMaluku.xlsx')
MALUKUUTs = pd.read_excel('/content/drive/My Drive/DQLAB/SEKOLAH/2019/NilaiUNMalukuUtara.xlsx')
NTBs = pd.read_excel('/content/drive/My Drive/DQLAB/SEKOLAH/2019/NilaiUNNTB.xlsx')
NTTs = pd.read_excel('/content/drive/My Drive/DQLAB/SEKOLAH/2019/NilaiUNNTT.xlsx')
BALIs = pd.read_excel('/content/drive/My Drive/DQLAB/SEKOLAH/2019/NilaiUNBali.xlsx')
PAPUAs = pd.read_excel('/content/drive/My Drive/DQLAB/SEKOLAH/2019/NilaiUNPapua.xlsx')
PAPUABARs = pd.read_excel('/content/drive/My Drive/DQLAB/SEKOLAH/2019/NilaiUNPapuaBarat.xlsx')

# %%
sekolah= [DKIs,DIYs,JABARs,JATENGs,JATIMs,BANTENs,LAMPUNGs,BELITUNGs,SUMSELs,RIAUs,BENGKULUs,SUMUTs,SUMBARs,ACEHs,KEPRIAUs,KALTIMs,KALBARs,KALTENGs
           ,KALUTs,KALSELs,SULSELs,SULUTs,SULTENGs,SULTENGGs,SULBARs,GORONTALOs,MALUKUs,MALUKUUTs,NTBs,NTTs,BALIs,PAPUAs,PAPUABARs]
for i in sekolah :
    i.rename(columns={'Unnamed: 1':'KODE', 'Unnamed: 2':'NAMA_SATUAN_PENDIDIKAN', 'Unnamed: 3':'NPSN','Unnamed: 4':'STATUS', 'Unnamed: 5':'JUMLAH_PESERTA', 
                    'Unnamed: 6':'BAHASA_INDONESIA', 'Unnamed: 7':'BAHASA_INGGRIS', 'Unnamed: 8':'MATEMATIKA', 'Unnamed: 9':'KOMPETENSI','Unnamed: 10':'RERATA_NILAI'},inplace=True )  
    i.dropna(inplace = True)
    i.drop(['CAPAIAN NILAI UJIAN NASIONAL'],axis=1)

# %%
SMK = pd.concat(sekolah)
SMK = SMK.drop(['CAPAIAN NILAI UJIAN NASIONAL'],axis=1)
SMK = SMK.sort_values('KODE',ascending = True)
SMK = SMK.reset_index()
SMK = SMK.drop(['index'],axis=1)
SMK.tail()
# Out:
#             KODE             NAMA_SATUAN_PENDIDIKAN  ... KOMPETENSI RERATA_NILAI
# 13338   34030009               SMKN 1 SEI-MENGGARIS  ...      48.56        47,44
# 13339   34040001               SMK NEGERI 1 MALINAU  ...      33.14        38,06
# 13340   34040002               SMK NEGERI 2 MALINAU  ...      36.25        39,90
# 13341   34040003  SMK SEHATI TANJUNG LAPANG MALINAU  ...      25.83        34,31
# 13342   34040004             SMK-SPP NEGERI MALINAU  ...      35.53        36,71
#
# [5 rows x 10 columns]

# %%
SMK.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13343 entries, 0 to 13342
# Data columns (total 10 columns):
# KODE                      13343 non-null object
# NAMA_SATUAN_PENDIDIKAN    13343 non-null object
# NPSN                      13343 non-null object
# STATUS                    13343 non-null object
# JUMLAH_PESERTA            13343 non-null object
# BAHASA_INDONESIA          13343 non-null object
# BAHASA_INGGRIS            13343 non-null object
# MATEMATIKA                13343 non-null object
# KOMPETENSI                13343 non-null object
# RERATA_NILAI              13343 non-null object
# dtypes: object(10)
# memory usage: 1.0+ MB

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 34 entries, 4 to 37
# Data columns (total 10 columns):
# CAPAIAN_NILAI_UJIAN_NASIONAL    34 non-null int64
# KODE                            34 non-null object
# NAMA_PROVINSI                   34 non-null object
# JUMLAH_SATUAN_PENDIDIKAN        34 non-null int64
# JUMLAH_PESERTA                  34 non-null int64
# BAHASA_INDONESIA                34 non-null float64
# BAHASA_INGGRIS                  34 non-null float64
# MATEMATIKA                      34 non-null float64
# KOMPETENSI                      34 non-null float64
# RERATA_NILAI                    34 non-null object
# dtypes: float64(4), int64(3), object(3)
# memory usage: 2.9+ KB

# %%
SMK = SMK.replace('-','0')
SMK[['BAHASA_INDONESIA', 'BAHASA_INGGRIS','MATEMATIKA','KOMPETENSI']] = SMK[['BAHASA_INDONESIA','BAHASA_INGGRIS','MATEMATIKA','KOMPETENSI']].apply(pd.to_numeric)

# %% [markdown]
# **5 SMK dengan Nilai Terbaik**

# %%
fig,axes = plt.subplots(2,2)
plt.subplots_adjust(wspace=0.75, hspace=0.3)
fig.set_size_inches(17, 12)
print('5 SMK dengan nilai terbaik')
sns.barplot(x='BAHASA_INDONESIA', y='NAMA_SATUAN_PENDIDIKAN', data=SMK.sort_values('BAHASA_INDONESIA',ascending = False).head(5),ax=axes[0,0],palette="cool")
sns.barplot(x='BAHASA_INGGRIS', y='NAMA_SATUAN_PENDIDIKAN', data=SMK.sort_values('BAHASA_INGGRIS',ascending = False).head(5),ax=axes[0,1],palette="cool")
sns.barplot(x='MATEMATIKA', y='NAMA_SATUAN_PENDIDIKAN', data=SMK.sort_values('MATEMATIKA',ascending = False).head(5),ax=axes[1,0],palette="cool")
sns.barplot(x='KOMPETENSI', y='NAMA_SATUAN_PENDIDIKAN', data=SMK.sort_values('KOMPETENSI',ascending = False).head(5),ax=axes[1,1],palette="cool")
# Out:
# 5 SMK dengan nilai terbaik

# %%
SMK=SMK.copy()
SMK = SMK.stack().str.replace(',','.').unstack()
SMK[['RERATA_NILAI']] = SMK[['RERATA_NILAI']].apply(pd.to_numeric)
plt.figure(figsize=(6,4))
sns.barplot(x='RERATA_NILAI', y='NAMA_SATUAN_PENDIDIKAN', data=SMK.sort_values('RERATA_NILAI',ascending = False).head(5),palette="cool")

# %%
negeri = SMK[SMK['STATUS'] == 'N']
swasta = SMK[SMK['STATUS'] == 'S']
negeri=negeri.reset_index()
negeri=negeri.drop(['index'],axis=1)
swasta=swasta.reset_index()
swasta=swasta.drop(['index'],axis=1)

# %%
negeri.tail()
# Out:
#            KODE  NAMA_SATUAN_PENDIDIKAN  ... KOMPETENSI RERATA_NILAI
# 3419   34030004     SMK NEGERI 1 KRAYAN  ...      41.94        42,04
# 3420   34030009    SMKN 1 SEI-MENGGARIS  ...      48.56        47,44
# 3421   34040001    SMK NEGERI 1 MALINAU  ...      33.14        38,06
# 3422   34040002    SMK NEGERI 2 MALINAU  ...      36.25        39,90
# 3423   34040004  SMK-SPP NEGERI MALINAU  ...      35.53        36,71
#
# [5 rows x 10 columns]

# %%
swasta.tail()
# Out:
#            KODE               NAMA_SATUAN_PENDIDIKAN  ... KOMPETENSI RERATA_NILAI
# 9914   34020008             SMK TERPADU CITRA BANGSA  ...      38.00        42,02
# 9915   34030005         SMK NURUL IMAN SEBATIK TIMUR  ...      34.57        40,05
# 9916   34030007           SMK MUTIARA BANGSA SEBATIK  ...      37.42        43,55
# 9917   34030008  SMKS KESEHATAN PUTRA BORNEO NUNUKAN  ...      41.04        40,69
# 9918   34040003    SMK SEHATI TANJUNG LAPANG MALINAU  ...      25.83        34,31
#
# [5 rows x 10 columns]

# %% [markdown]
# **5 SMK Negeri dengan nilai terbaik**

# %%
fig,axes = plt.subplots(2,2)
plt.subplots_adjust(wspace=0.75, hspace=0.3)
fig.set_size_inches(17, 12)
print('5 SMA Negeri SMK dengan nilai terbaik')
sns.barplot(x='BAHASA_INDONESIA', y='NAMA_SATUAN_PENDIDIKAN', data=negeri.sort_values('BAHASA_INDONESIA',ascending = False).head(5),ax=axes[0,0],palette="cool")
sns.barplot(x='BAHASA_INGGRIS', y='NAMA_SATUAN_PENDIDIKAN', data=negeri.sort_values('BAHASA_INGGRIS',ascending = False).head(5),ax=axes[0,1],palette="cool")
sns.barplot(x='MATEMATIKA', y='NAMA_SATUAN_PENDIDIKAN', data=negeri.sort_values('MATEMATIKA',ascending = False).head(5),ax=axes[1,0],palette="cool")
sns.barplot(x='KOMPETENSI', y='NAMA_SATUAN_PENDIDIKAN', data=negeri.sort_values('KOMPETENSI',ascending = False).head(5),ax=axes[1,1],palette="cool")
# Out:
# 5 SMA Negeri SMK dengan nilai terbaik

# %%
sns.barplot(x='RERATA_NILAI', y='NAMA_SATUAN_PENDIDIKAN', data=negeri.sort_values('RERATA_NILAI',ascending = False).head(5),palette="cool")

# %% [markdown]
# **5 SMK Swasta dengan nilai Terbaik**

# %%
fig,axes = plt.subplots(2,2)
plt.subplots_adjust(wspace=0.75, hspace=0.3)
fig.set_size_inches(22, 12)
print('5 SMA Swasta jurusan SMK dengan nilai terbaik ')
sns.barplot(x='BAHASA_INDONESIA', y='NAMA_SATUAN_PENDIDIKAN', data=swasta.sort_values('BAHASA_INDONESIA',ascending = False).head(5),ax=axes[0,0],palette="cool")
sns.barplot(x='BAHASA_INGGRIS', y='NAMA_SATUAN_PENDIDIKAN', data=swasta.sort_values('BAHASA_INGGRIS',ascending = False).head(5),ax=axes[0,1],palette="cool")
sns.barplot(x='MATEMATIKA', y='NAMA_SATUAN_PENDIDIKAN', data=swasta.sort_values('MATEMATIKA',ascending = False).head(5),ax=axes[1,0],palette="cool")
sns.barplot(x='KOMPETENSI', y='NAMA_SATUAN_PENDIDIKAN', data=swasta.sort_values('KOMPETENSI',ascending = False).head(5),ax=axes[1,1],palette="cool")
# Out:
# 5 SMA Swasta jurusan SMK dengan nilai terbaik

# %%
sns.barplot(x='RERATA_NILAI', y='NAMA_SATUAN_PENDIDIKAN', data=swasta.sort_values('RERATA_NILAI',ascending = False).head(5),palette="cool")
