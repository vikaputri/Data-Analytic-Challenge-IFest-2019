# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # A. TINGKAT NASIONAL DAN PROVINSI

# %% [markdown]
# **1. Load dataset & pra-proses data untuk tingkat provinsi periode 2019**

# %%
df = pd.read_excel('/content/drive/My Drive/IFEST/PAKET C/IPS/CAPAIAN NILAI UJIAN NASIONAL PAKETC TAHUN AJARAN 2018-2019_ .xlsx')

# %%
df.head(5)
# Out:
#   CAPAIAN NILAI UJIAN NASIONAL Unnamed: 1  ... Unnamed: 11   Unnamed: 12
# 0    TAHUN PELAJARAN 2018/2019        NaN  ...         NaN           NaN
# 1                          NaN        NaN  ...         NaN           NaN
# 2                           NO       KODE  ...         NaN  RERATA NILAI
# 3                          NaN        NaN  ...         PKN           NaN
# 4                            1         01  ...       39.25         35,48
#
# [5 rows x 13 columns]

# %% [markdown]
# Pra-proses data(data cleaning)

# %%
df.rename(columns={'Unnamed: 1':'KODE', 'Unnamed: 2':'NAMA PROVINSI', 'Unnamed: 3':'JUMLAH SATUAN PENDIDIKAN', 'Unnamed: 4':'JUMLAH PESERTA', 'Unnamed: 5':'BAHASA INDONESIA', 'Unnamed: 6':'BAHASA INGGRIS', 'Unnamed: 7':'MATEMATIKA', 'Unnamed: 8':'EKONOMI','Unnamed: 9':'SOSIOLOGI', 'Unnamed: 10':'GEOGRAFI', 'Unnamed: 11':'PKN','Unnamed: 12':'RERATA NILAI'},inplace=True )

# %%
dfcopy=df.copy()
dfcopy.dropna(inplace = True)
dfcopy=dfcopy.drop(['CAPAIAN NILAI UJIAN NASIONAL'],axis=1)
dfcopy.tail(3)
# Out:
#    KODE     NAMA PROVINSI JUMLAH SATUAN PENDIDIKAN  ... GEOGRAFI    PKN RERATA NILAI
# 36   33       PAPUA BARAT                       43  ...    26.18  27.99        25,80
# 37   34  KALIMANTAN UTARA                       36  ...    24.69  27.84        25,54
# 38   91              SILN                        7  ...    36.47  42.49        37,46
#
# [3 rows x 12 columns]

# %%
df.dropna(inplace = True)
df=df.drop(['CAPAIAN NILAI UJIAN NASIONAL'],axis=1)
df.head(2)
# Out:
#   KODE NAMA PROVINSI JUMLAH SATUAN PENDIDIKAN  ... GEOGRAFI    PKN RERATA NILAI
# 4   01   DKI JAKARTA                      218  ...    35.07  39.25        35,48
# 5   02    JAWA BARAT                     1019  ...    29.76  32.16        29,77
#
# [2 rows x 12 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 35 entries, 4 to 38
# Data columns (total 12 columns):
# KODE                        35 non-null object
# NAMA PROVINSI               35 non-null object
# JUMLAH SATUAN PENDIDIKAN    35 non-null object
# JUMLAH PESERTA              35 non-null object
# BAHASA INDONESIA            35 non-null object
# BAHASA INGGRIS              35 non-null object
# MATEMATIKA                  35 non-null object
# EKONOMI                     35 non-null object
# SOSIOLOGI                   35 non-null object
# GEOGRAFI                    35 non-null object
# PKN                         35 non-null object
# RERATA NILAI                35 non-null object
# dtypes: object(12)
# memory usage: 3.6+ KB

# %%
df[['BAHASA INDONESIA', 'BAHASA INGGRIS','MATEMATIKA','EKONOMI','SOSIOLOGI','GEOGRAFI','PKN']] = df[['BAHASA INDONESIA', 
                                                                                                'BAHASA INGGRIS','MATEMATIKA',
                                                                                                'EKONOMI','SOSIOLOGI','GEOGRAFI','PKN']].apply(pd.to_numeric)

# %% [markdown]
# **2.Visualisasi Data**

# %% [markdown]
# **Jumlah Peserta UN Paket C Jurusan IPS**

# %%
plt.figure(figsize=(8,9))
print('JUMLAH PESERTA UN PAKET C JURUSAN IPS')
ax=sns.barplot(x='JUMLAH PESERTA', y='NAMA PROVINSI', data = dfcopy.sort_values('JUMLAH PESERTA',ascending=False),palette="cool")
ax.set_xlabel('JUMLAH PESERTA')
# Out:
# JUMLAH PESERTA UN PAKET C JURUSAN IPS
# Text(0.5, 0, 'JUMLAH PESERTA')

# %% [markdown]
# **Nilai UN Tertinggi tiap mata-pelajaran Paket C jurusan IPS pada tahun 2019 tingkat Provinsi**

# %%
fig,axes = plt.subplots(7)
plt.subplots_adjust(wspace=0.75, hspace=0.3)
fig.set_size_inches(5, 20)
print('5 Provinsi dengan Rata-Rata Nilai UN Tertinggi untuk Setiap Mata Pelajaran')
sns.barplot(x='BAHASA INDONESIA', y='NAMA PROVINSI', data=df.sort_values('BAHASA INDONESIA',ascending = False).head(5),ax=axes[0],palette="cool")
sns.barplot(x='BAHASA INGGRIS', y='NAMA PROVINSI', data=df.sort_values('BAHASA INGGRIS',ascending = False).head(5),ax=axes[1],palette="cool")
sns.barplot(x='MATEMATIKA', y='NAMA PROVINSI', data=df.sort_values('MATEMATIKA',ascending = False).head(5),ax=axes[2],palette="cool")
sns.barplot(x='EKONOMI', y='NAMA PROVINSI', data=df.sort_values('EKONOMI',ascending = False).head(5),ax=axes[3],palette="cool")
sns.barplot(x='SOSIOLOGI', y='NAMA PROVINSI', data=df.sort_values('SOSIOLOGI',ascending = False).head(5),ax=axes[4],palette="cool")
sns.barplot(x='GEOGRAFI', y='NAMA PROVINSI', data=df.sort_values('GEOGRAFI',ascending = False).head(5),ax=axes[5],palette="cool")
sns.barplot(x='PKN', y='NAMA PROVINSI', data=df.sort_values('PKN',ascending = False).head(5),ax=axes[6],palette="cool")
# Out:
# 5 Provinsi dengan Rata-Rata Nilai UN Tertinggi untuk Setiap Mata Pelajaran

# %% [markdown]
# **Nilai UN terendah tiap mata-pelajaran Paket C jurusan IPS pada tahun 2019 tingkat Provinsi**

# %%
fig,axes = plt.subplots(7)
plt.subplots_adjust(wspace=0.75, hspace=0.3)
fig.set_size_inches(5, 20)
print('5 Provinsi dengan Rata-Rata Nilai UN Tertinggi untuk Setiap Mata Pelajaran')
sns.barplot(x='BAHASA INDONESIA', y='NAMA PROVINSI', data=df.sort_values('BAHASA INDONESIA',ascending = False).tail(5),ax=axes[0],palette="cool")
sns.barplot(x='BAHASA INGGRIS', y='NAMA PROVINSI', data=df.sort_values('BAHASA INGGRIS',ascending = False).tail(5),ax=axes[1],palette="cool")
sns.barplot(x='MATEMATIKA', y='NAMA PROVINSI', data=df.sort_values('MATEMATIKA',ascending = False).tail(5),ax=axes[2],palette="cool")
sns.barplot(x='EKONOMI', y='NAMA PROVINSI', data=df.sort_values('EKONOMI',ascending = False).tail(5),ax=axes[3],palette="cool")
sns.barplot(x='SOSIOLOGI', y='NAMA PROVINSI', data=df.sort_values('SOSIOLOGI',ascending = False).tail(5),ax=axes[4],palette="cool")
sns.barplot(x='GEOGRAFI', y='NAMA PROVINSI', data=df.sort_values('GEOGRAFI',ascending = False).tail(5),ax=axes[5],palette="cool")
sns.barplot(x='PKN', y='NAMA PROVINSI', data=df.sort_values('PKN',ascending = False).tail(5),ax=axes[6],palette="cool")
# Out:
# 5 Provinsi dengan Rata-Rata Nilai UN Tertinggi untuk Setiap Mata Pelajaran

# %% [markdown]
# **Perolehan 5 nilai Rata-Rata UN Tertinggi dan Terendah Paket C Jurusan IPS Tingkat Provinsi**

# %%
df1=df.copy()
df1 = df1.stack().str.replace(',','.').unstack()
df1[['RERATA NILAI']] = df1[['RERATA NILAI']].apply(pd.to_numeric)
fig,axes = plt.subplots(2)
plt.subplots_adjust(wspace=0.75, hspace=0.3)
fig.set_size_inches(8, 7)
print('RERATA TERTINGGI UN PAKET C JURUSAN IPS')
sns.barplot(x='RERATA NILAI', y='NAMA PROVINSI', data=df1.sort_values('RERATA NILAI',ascending = False).head(5),ax=axes[0],palette="cool")
sns.barplot(x='RERATA NILAI', y='NAMA PROVINSI', data=df1.sort_values('RERATA NILAI',ascending = False).tail(5),ax=axes[1],palette="OrRd")
# Out:
# RERATA TERTINGGI UN PAKET C JURUSAN IPS

# %% [markdown]
# **Penguasaan Masing-Masing Mata Pelajaran Paket Jurusan IPS Tingkat Provinsi**

# %%
plt.figure(figsize=(8,15))
sns.barplot(x='BAHASA INDONESIA', y='NAMA PROVINSI', data=df.sort_values('BAHASA INDONESIA',ascending = False),palette="cool",)

# %%
plt.figure(figsize=(8,15))
sns.barplot(x='BAHASA INGGRIS', y='NAMA PROVINSI', data=dfcopy.sort_values('BAHASA INGGRIS',ascending = False),palette="coolwarm")

# %%
plt.figure(figsize=(8,15))
sns.barplot(x='MATEMATIKA', y='NAMA PROVINSI', data=df.sort_values('MATEMATIKA',ascending = False),palette="rainbow")

# %%
plt.figure(figsize=(8,15))
sns.barplot(x='EKONOMI', y='NAMA PROVINSI', data=df.sort_values('EKONOMI',ascending = False),palette="cool")

# %%
plt.figure(figsize=(8,15))
sns.barplot(x='SOSIOLOGI', y='NAMA PROVINSI', data=df.sort_values('SOSIOLOGI',ascending = False),palette="terrain")

# %%
plt.figure(figsize=(8,15))
sns.barplot(x='GEOGRAFI', y='NAMA PROVINSI', data=df.sort_values('GEOGRAFI',ascending = False),palette="cool")

# %%
plt.figure(figsize=(8,15))
sns.barplot(x='PKN', y='NAMA PROVINSI', data=df.sort_values('PKN',ascending = False),palette="cool")

# %% [markdown]
# # B. Tingkat Kota/Kabupaten

# %% [markdown]
# **1. Load dataset & pra-proses data untuk tingkat kabupaten/kota periode 2019**

# %%
df = pd.read_excel('/content/drive/My Drive/IFEST/PAKET C/IPS/CAPAIAN NILAI UJIAN NASIONAL PAKETC TAHUN AJARAN 2018-2019(perkota).xlsx')

# %%
df.head(5)
# Out:
#   CAPAIAN NILAI UJIAN NASIONAL Unnamed: 1  ... Unnamed: 11   Unnamed: 12
# 0    TAHUN PELAJARAN 2018/2019        NaN  ...         NaN           NaN
# 1                          NaN        NaN  ...         NaN           NaN
# 2                           NO       KODE  ...         NaN  RERATA NILAI
# 3                          NaN        NaN  ...         PKN           NaN
# 4                            1       0101  ...       52.09         49,23
#
# [5 rows x 13 columns]

# %% [markdown]
# Pra-proses data(data cleaning)

# %%
df.rename(columns={'Unnamed: 1':'KODE', 'Unnamed: 2':'NAMA KOTA/KABUPATEN', 'Unnamed: 3':'JUMLAH SATUAN PENDIDIKAN', 'Unnamed: 4':'JUMLAH PESERTA', 'Unnamed: 5':'BAHASA INDONESIA', 'Unnamed: 6':'BAHASA INGGRIS', 'Unnamed: 7':'MATEMATIKA', 'Unnamed: 8':'EKONOMI','Unnamed: 9':'SOSIOLOGI', 'Unnamed: 10':'GEOGRAFI', 'Unnamed: 11':'PKN','Unnamed: 12':'RERATA NILAI'},inplace=True )

# %%
dfcopy=df.copy()
dfcopy.dropna(inplace = True)
dfcopy=dfcopy.drop(['CAPAIAN NILAI UJIAN NASIONAL'],axis=1)
dfcopy.tail(2)
# Out:
#       KODE NAMA KOTA/KABUPATEN  ...    PKN RERATA NILAI
# 484   9113              TAIWAN  ...  40.12        36,20
# 485   9114            HONGKONG  ...  44.46        38,17
#
# [2 rows x 12 columns]

# %%
df.dropna(inplace = True)
df=df.drop(['CAPAIAN NILAI UJIAN NASIONAL'],axis=1)
df.head(2)
# Out:
#     KODE NAMA KOTA/KABUPATEN  ...    PKN RERATA NILAI
# 4   0101  KOTA JAKARTA PUSAT  ...  52.09        49,23
# 5   0102  KOTA JAKARTA UTARA  ...  35.75        32,22
#
# [2 rows x 12 columns]

# %% [markdown]
# **2.Visualisasi**

# %% [markdown]
# **Nilai UN Tertinggi tiap mata-pelajaran Paket C jurusan IPS pada tahun 2019 tingkat Kabupaten/Kota**

# %%
df = df.replace('-','0')
fig,axes = plt.subplots(5)
plt.subplots_adjust(wspace=0.75, hspace=0.3)
fig.set_size_inches(5, 20)
print('5 Provinsi dengan Rata-Rata Nilai UN Tertinggi untuk Setiap Mata Pelajaran')
sns.barplot(x='BAHASA INDONESIA', y='NAMA KOTA/KABUPATEN', data=df.sort_values('BAHASA INDONESIA',ascending = False).head(5),ax=axes[0],palette="cool")
sns.barplot(x='BAHASA INGGRIS', y='NAMA KOTA/KABUPATEN', data=df.sort_values('BAHASA INGGRIS',ascending = False).head(5),ax=axes[1],palette="cool")
sns.barplot(x='EKONOMI', y='NAMA KOTA/KABUPATEN', data=df.sort_values('EKONOMI',ascending = False).head(5),ax=axes[2],palette="cool")
sns.barplot(x='GEOGRAFI', y='NAMA KOTA/KABUPATEN', data=df.sort_values('GEOGRAFI',ascending = False).head(5),ax=axes[3],palette="cool")
sns.barplot(x='PKN', y='NAMA KOTA/KABUPATEN', data=df.sort_values('PKN',ascending = False).head(5),ax=axes[4],palette="cool")
# Out:
# 5 Provinsi dengan Rata-Rata Nilai UN Tertinggi untuk Setiap Mata Pelajaran

# %% [markdown]
# **5 Kabupaten/Kota dengan Nilai Rata-Rata UN Tertinggi Paket C IPS**

# %%
df1=df.copy()
df1 = df1.stack().str.replace(',','.').unstack()
df1[['RERATA NILAI']] = df1[['RERATA NILAI']].apply(pd.to_numeric)
plt.figure(figsize=(6,4))
sns.barplot(x='RERATA NILAI', y='NAMA KOTA/KABUPATEN', data=df1.sort_values('RERATA NILAI',ascending = False).head(5),palette="cool")

# %% [markdown]
# **5 Kabupaten/Kota dengan Nilai Rata-Rata UN Terendah Paket C IPS**

# %%
plt.figure(figsize=(6,4))
sns.barplot(x='RERATA NILAI', y='NAMA KOTA/KABUPATEN', data=df1.sort_values('RERATA NILAI',ascending = False).tail(5),palette="cool")

# %% [markdown]
# **50 Kabupaten/Kota Nilai UN Terendah Tiap Mata Pelajaran**

# %%
plt.figure(figsize=(8,15))
sns.barplot(x='BAHASA INDONESIA', y='NAMA KOTA/KABUPATEN', data=df.sort_values('BAHASA INDONESIA',ascending = False).tail(50),palette="cool")

# %%
plt.figure(figsize=(8,15))
sns.barplot(x='GEOGRAFI', y='NAMA KOTA/KABUPATEN', data=df.sort_values('GEOGRAFI',ascending = False).tail(50),palette="cool")

# %%
plt.figure(figsize=(8,15))
sns.barplot(x='EKONOMI', y='NAMA KOTA/KABUPATEN', data=df.sort_values('EKONOMI',ascending = False).tail(50),palette="cool")

# %%
plt.figure(figsize=(8,15))
sns.barplot(x='BAHASA INGGRIS', y='NAMA KOTA/KABUPATEN', data=df.sort_values('BAHASA INGGRIS',ascending = False).tail(50),palette="cool")

# %%
plt.figure(figsize=(8,15))
sns.barplot(x='PKN', y='NAMA KOTA/KABUPATEN', data=df.sort_values('PKN',ascending = False).tail(50),palette="cool")

# %% [markdown]
# # C. Tingkat Sekolah

# %% [markdown]
# **1. Load dataset & pra-proses data untuk tingkat sekolah periode 2019**

# %%
DKI = pd.read_excel('/content/drive/My Drive/IFEST/PAKET C/IPS/persekolah/CAPAIAN NILAI UJIAN NASIONAL PAKETC TAHUN AJARAN 2018-2019_ .xlsx')
jabar = pd.read_excel('/content/drive/My Drive/IFEST/PAKET C/IPS/persekolah/CAPAIAN NILAI UJIAN NASIONAL PAKETC TAHUN AJARAN 2018-2019_ (1).xlsx')
jateng = pd.read_excel('/content/drive/My Drive/IFEST/PAKET C/IPS/persekolah/CAPAIAN NILAI UJIAN NASIONAL PAKETC TAHUN AJARAN 2018-2019_ (2).xlsx')
DIY = pd.read_excel('/content/drive/My Drive/IFEST/PAKET C/IPS/persekolah/CAPAIAN NILAI UJIAN NASIONAL PAKETC TAHUN AJARAN 2018-2019_ (3).xlsx')
jatim = pd.read_excel('/content/drive/My Drive/IFEST/PAKET C/IPS/persekolah/CAPAIAN NILAI UJIAN NASIONAL PAKETC TAHUN AJARAN 2018-2019_ (4).xlsx')
aceh = pd.read_excel('/content/drive/My Drive/IFEST/PAKET C/IPS/persekolah/CAPAIAN NILAI UJIAN NASIONAL PAKETC TAHUN AJARAN 2018-2019_ (5).xlsx')
sumut = pd.read_excel('/content/drive/My Drive/IFEST/PAKET C/IPS/persekolah/CAPAIAN NILAI UJIAN NASIONAL PAKETC TAHUN AJARAN 2018-2019_ (6).xlsx')
sumbar = pd.read_excel('/content/drive/My Drive/IFEST/PAKET C/IPS/persekolah/CAPAIAN NILAI UJIAN NASIONAL PAKETC TAHUN AJARAN 2018-2019_ (7).xlsx')
riau = pd.read_excel('/content/drive/My Drive/IFEST/PAKET C/IPS/persekolah/CAPAIAN NILAI UJIAN NASIONAL PAKETC TAHUN AJARAN 2018-2019_ (8).xlsx')
jambi = pd.read_excel('/content/drive/My Drive/IFEST/PAKET C/IPS/persekolah/CAPAIAN NILAI UJIAN NASIONAL PAKETC TAHUN AJARAN 2018-2019_ (9).xlsx')
sumsel = pd.read_excel('/content/drive/My Drive/IFEST/PAKET C/IPS/persekolah/CAPAIAN NILAI UJIAN NASIONAL PAKETC TAHUN AJARAN 2018-2019_ (10).xlsx')
lampung= pd.read_excel('/content/drive/My Drive/IFEST/PAKET C/IPS/persekolah/CAPAIAN NILAI UJIAN NASIONAL PAKETC TAHUN AJARAN 2018-2019_ (11).xlsx')
kalbar = pd.read_excel('/content/drive/My Drive/IFEST/PAKET C/IPS/persekolah/CAPAIAN NILAI UJIAN NASIONAL PAKETC TAHUN AJARAN 2018-2019_ (12).xlsx')
kalteng = pd.read_excel('/content/drive/My Drive/IFEST/PAKET C/IPS/persekolah/CAPAIAN NILAI UJIAN NASIONAL PAKETC TAHUN AJARAN 2018-2019_ (13).xlsx')
kalsel = pd.read_excel('/content/drive/My Drive/IFEST/PAKET C/IPS/persekolah/CAPAIAN NILAI UJIAN NASIONAL PAKETC TAHUN AJARAN 2018-2019_ (14).xlsx')
kaltim = pd.read_excel('/content/drive/My Drive/IFEST/PAKET C/IPS/persekolah/CAPAIAN NILAI UJIAN NASIONAL PAKETC TAHUN AJARAN 2018-2019_ (15).xlsx')
sulut = pd.read_excel('/content/drive/My Drive/IFEST/PAKET C/IPS/persekolah/CAPAIAN NILAI UJIAN NASIONAL PAKETC TAHUN AJARAN 2018-2019_ (16).xlsx')
sulteng = pd.read_excel('/content/drive/My Drive/IFEST/PAKET C/IPS/persekolah/CAPAIAN NILAI UJIAN NASIONAL PAKETC TAHUN AJARAN 2018-2019_ (17).xlsx')
sulsel = pd.read_excel('/content/drive/My Drive/IFEST/PAKET C/IPS/persekolah/CAPAIAN NILAI UJIAN NASIONAL PAKETC TAHUN AJARAN 2018-2019_ (18).xlsx')
sultengg= pd.read_excel('/content/drive/My Drive/IFEST/PAKET C/IPS/persekolah/CAPAIAN NILAI UJIAN NASIONAL PAKETC TAHUN AJARAN 2018-2019_ (19).xlsx')
maluku = pd.read_excel('/content/drive/My Drive/IFEST/PAKET C/IPS/persekolah/CAPAIAN NILAI UJIAN NASIONAL PAKETC TAHUN AJARAN 2018-2019_ (20).xlsx')
bali = pd.read_excel('/content/drive/My Drive/IFEST/PAKET C/IPS/persekolah/CAPAIAN NILAI UJIAN NASIONAL PAKETC TAHUN AJARAN 2018-2019_ (21).xlsx')
NTB = pd.read_excel('/content/drive/My Drive/IFEST/PAKET C/IPS/persekolah/CAPAIAN NILAI UJIAN NASIONAL PAKETC TAHUN AJARAN 2018-2019_ (22).xlsx')
NTT = pd.read_excel('/content/drive/My Drive/IFEST/PAKET C/IPS/persekolah/CAPAIAN NILAI UJIAN NASIONAL PAKETC TAHUN AJARAN 2018-2019_ (23).xlsx')
papua = pd.read_excel('/content/drive/My Drive/IFEST/PAKET C/IPS/persekolah/CAPAIAN NILAI UJIAN NASIONAL PAKETC TAHUN AJARAN 2018-2019_ (24).xlsx')
bengkulu = pd.read_excel('/content/drive/My Drive/IFEST/PAKET C/IPS/persekolah/CAPAIAN NILAI UJIAN NASIONAL PAKETC TAHUN AJARAN 2018-2019_ (25).xlsx')
malut= pd.read_excel('/content/drive/My Drive/IFEST/PAKET C/IPS/persekolah/CAPAIAN NILAI UJIAN NASIONAL PAKETC TAHUN AJARAN 2018-2019_ (26).xlsx')
bangkabel = pd.read_excel('/content/drive/My Drive/IFEST/PAKET C/IPS/persekolah/CAPAIAN NILAI UJIAN NASIONAL PAKETC TAHUN AJARAN 2018-2019_ (27).xlsx')
goront = pd.read_excel('/content/drive/My Drive/IFEST/PAKET C/IPS/persekolah/CAPAIAN NILAI UJIAN NASIONAL PAKETC TAHUN AJARAN 2018-2019_ (28).xlsx')
banten = pd.read_excel('/content/drive/My Drive/IFEST/PAKET C/IPS/persekolah/CAPAIAN NILAI UJIAN NASIONAL PAKETC TAHUN AJARAN 2018-2019_ (29).xlsx')
kepriau = pd.read_excel('/content/drive/My Drive/IFEST/PAKET C/IPS/persekolah/CAPAIAN NILAI UJIAN NASIONAL PAKETC TAHUN AJARAN 2018-2019_ (30).xlsx')
sulbar = pd.read_excel('/content/drive/My Drive/IFEST/PAKET C/IPS/persekolah/CAPAIAN NILAI UJIAN NASIONAL PAKETC TAHUN AJARAN 2018-2019_ (31).xlsx')
papbar = pd.read_excel('/content/drive/My Drive/IFEST/PAKET C/IPS/persekolah/CAPAIAN NILAI UJIAN NASIONAL PAKETC TAHUN AJARAN 2018-2019_ (32).xlsx')
kalut = pd.read_excel('/content/drive/My Drive/IFEST/PAKET C/IPS/persekolah/CAPAIAN NILAI UJIAN NASIONAL PAKETC TAHUN AJARAN 2018-2019_ (33).xlsx')

# %%
kalut.head(5)
# Out:
#   CAPAIAN NILAI UJIAN NASIONAL Unnamed: 1  ... Unnamed: 12   Unnamed: 13
# 0    TAHUN PELAJARAN 2018/2019        NaN  ...         NaN           NaN
# 1                          NaN        NaN  ...         NaN           NaN
# 2                           NO       KODE  ...         NaN  RERATA NILAI
# 3                          NaN        NaN  ...         PKN           NaN
# 4                            1   34010002  ...       35.76         30,74
#
# [5 rows x 14 columns]

# %% [markdown]
# Pra-proses data(data cleaning)

# %%
sekolah= [DKI,jabar,jateng,DIY,jatim,aceh,sumut,sumbar,riau,jambi,sumsel,lampung,kalbar,kalteng,kalsel,kaltim,sulut,sulteng,sulsel,sultengg,maluku,bali,NTB,NTT,papua,bengkulu,malut,bangkabel,goront,banten,kepriau,sulbar,papbar,kalut]
for i in sekolah :
    i.rename(columns={'Unnamed: 1':'KODE', 'Unnamed: 2':'NAMA SATUAN PENDIDIKAN', 'Unnamed: 3':'NPSN','Unnamed: 4':'STATUS', 'Unnamed: 5':'JUMLAH PESERTA','Unnamed: 6':'BAHASA INDONESIA', 'Unnamed: 7':'BAHASA INGGRIS', 'Unnamed: 8':'MATEMATIKA', 'Unnamed: 9':'EKONOMI','Unnamed: 10':'SOSIOLOGI', 'Unnamed: 11':'GEOGRAFI', 'Unnamed: 12':'PKN', 'Unnamed: 13':'RERATA NILAI'},inplace=True)
    i.drop(['NPSN'],axis=1)

# %%
DKI.head()
# Out:
#   CAPAIAN NILAI UJIAN NASIONAL       KODE  ...    PKN  RERATA NILAI
# 0    TAHUN PELAJARAN 2018/2019        NaN  ...    NaN           NaN
# 1                          NaN        NaN  ...    NaN           NaN
# 2                           NO       KODE  ...    NaN  RERATA NILAI
# 3                          NaN        NaN  ...    PKN           NaN
# 4                            1   01010001  ...  39.36         33,68
#
# [5 rows x 14 columns]

# %%
DKI = DKI.drop(['NPSN'],axis=1)
DKI = DKI.copy()
DKI.dropna(inplace = True)
DKI = DKI.drop(['CAPAIAN NILAI UJIAN NASIONAL'],axis=1)
DKI = DKI.reset_index()
DKI = DKI.drop(['index'],axis=1)

jabar = jabar.drop(['NPSN'],axis=1)
jabar = jabar.copy()
jabar.dropna(inplace = True)
jabar = jabar.drop(['CAPAIAN NILAI UJIAN NASIONAL'],axis=1)
jabar = jabar.reset_index()
jabar = jabar.drop(['index'],axis=1)

jateng = jateng.drop(['NPSN'],axis=1)
jateng = jateng.copy()
jateng.dropna(inplace = True)
jateng = jateng.drop(['CAPAIAN NILAI UJIAN NASIONAL'],axis=1)
jateng = jateng.reset_index()
jateng = jateng.drop(['index'],axis=1)

DIY = DIY.drop(['NPSN'],axis=1)
DIY = DIY.copy()
DIY.dropna(inplace = True)
DIY = DIY.drop(['CAPAIAN NILAI UJIAN NASIONAL'],axis=1)
DIY = DIY.reset_index()
DIY = DIY.drop(['index'],axis=1)

jatim = jatim.drop(['NPSN'],axis=1)
jatim = jatim.copy()
jatim.dropna(inplace = True)
jatim = jatim.drop(['CAPAIAN NILAI UJIAN NASIONAL'],axis=1)
jatim = jatim.reset_index()
jatim = jatim.drop(['index'],axis=1)

aceh = aceh.drop(['NPSN'],axis=1)
aceh = aceh.copy()
aceh.dropna(inplace = True)
aceh = aceh.drop(['CAPAIAN NILAI UJIAN NASIONAL'],axis=1)
aceh = aceh.reset_index()
aceh = aceh.drop(['index'],axis=1)

sumut = sumut.drop(['NPSN'],axis=1)
sumut = sumut.copy()
sumut.dropna(inplace = True)
sumut = sumut.drop(['CAPAIAN NILAI UJIAN NASIONAL'],axis=1)
sumut = sumut.reset_index()
sumut = sumut.drop(['index'],axis=1)

sumbar = sumbar.drop(['NPSN'],axis=1)
sumbar = sumbar.copy()
sumbar.dropna(inplace = True)
sumbar = sumbar.drop(['CAPAIAN NILAI UJIAN NASIONAL'],axis=1)
sumbar = sumbar.reset_index()
sumbar = sumbar.drop(['index'],axis=1)

riau = riau.drop(['NPSN'],axis=1)
riau = riau.copy()
riau.dropna(inplace = True)
riau = riau.drop(['CAPAIAN NILAI UJIAN NASIONAL'],axis=1)
riau = riau.reset_index()
riau = riau.drop(['index'],axis=1)

jambi = jambi.drop(['NPSN'],axis=1)
jambi = jambi.copy()
jambi.dropna(inplace = True)
jambi = jambi.drop(['CAPAIAN NILAI UJIAN NASIONAL'],axis=1)
jambi = jambi.reset_index()
jambi = jambi.drop(['index'],axis=1)

sumsel = sumsel.drop(['NPSN'],axis=1)
sumsel = sumsel.copy()
sumsel.dropna(inplace = True)
sumsel = sumsel.drop(['CAPAIAN NILAI UJIAN NASIONAL'],axis=1)
sumsel = sumsel.reset_index()
sumsel = sumsel.drop(['index'],axis=1)

lampung = lampung.drop(['NPSN'],axis=1)
lampung = lampung.copy()
lampung.dropna(inplace = True)
lampung = lampung.drop(['CAPAIAN NILAI UJIAN NASIONAL'],axis=1)
lampung = lampung.reset_index()
lampung = lampung.drop(['index'],axis=1)

kalbar = kalbar.drop(['NPSN'],axis=1)
kalbar = kalbar.copy()
kalbar.dropna(inplace = True)
kalbar = kalbar.drop(['CAPAIAN NILAI UJIAN NASIONAL'],axis=1)
kalbar = kalbar.reset_index()
kalbar = kalbar.drop(['index'],axis=1)

kalteng = kalteng.drop(['NPSN'],axis=1)
kalteng = kalteng.copy()
kalteng.dropna(inplace = True)
kalteng = kalteng.drop(['CAPAIAN NILAI UJIAN NASIONAL'],axis=1)
kalteng = kalteng.reset_index()
kalteng = kalteng.drop(['index'],axis=1)

kalsel = kalsel.drop(['NPSN'],axis=1)
kalsel = kalsel.copy()
kalsel.dropna(inplace = True)
kalsel = kalsel.drop(['CAPAIAN NILAI UJIAN NASIONAL'],axis=1)
kalsel = kalsel.reset_index()
kalsel = kalsel.drop(['index'],axis=1)

kaltim = kaltim.drop(['NPSN'],axis=1)
kaltim = kaltim.copy()
kaltim.dropna(inplace = True)
kaltim = kaltim.drop(['CAPAIAN NILAI UJIAN NASIONAL'],axis=1)
kaltim = kaltim.reset_index()
kaltim = kaltim.drop(['index'],axis=1)

sulut = sulut.drop(['NPSN'],axis=1)
sulut = sulut.copy()
sulut.dropna(inplace = True)
sulut = sulut.drop(['CAPAIAN NILAI UJIAN NASIONAL'],axis=1)
sulut = sulut.reset_index()
sulut = sulut.drop(['index'],axis=1)

sulteng = sulteng.drop(['NPSN'],axis=1)
sulteng = sulteng.copy()
sulteng.dropna(inplace = True)
sulteng = sulteng.drop(['CAPAIAN NILAI UJIAN NASIONAL'],axis=1)
sulteng = sulteng.reset_index()
sulteng = sulteng.drop(['index'],axis=1)

sulsel = sulsel.drop(['NPSN'],axis=1)
sulsel = sulsel.copy()
sulsel.dropna(inplace = True)
sulsel = sulsel.drop(['CAPAIAN NILAI UJIAN NASIONAL'],axis=1)
sulsel = sulsel.reset_index()
sulsel = sulsel.drop(['index'],axis=1)

sultengg = sultengg.drop(['NPSN'],axis=1)
sultengg = sultengg.copy()
sultengg.dropna(inplace = True)
sultengg = sultengg.drop(['CAPAIAN NILAI UJIAN NASIONAL'],axis=1)
sultengg = sultengg.reset_index()
sultengg = sultengg.drop(['index'],axis=1)

maluku = maluku.drop(['NPSN'],axis=1)
maluku = maluku.copy()
maluku.dropna(inplace = True)
maluku = maluku.drop(['CAPAIAN NILAI UJIAN NASIONAL'],axis=1)
maluku = maluku.reset_index()
maluku = maluku.drop(['index'],axis=1)

bali = bali.drop(['NPSN'],axis=1)
bali = bali.copy()
bali.dropna(inplace = True)
bali = bali.drop(['CAPAIAN NILAI UJIAN NASIONAL'],axis=1)
bali = bali.reset_index()
bali = bali.drop(['index'],axis=1)

NTB = NTB.drop(['NPSN'],axis=1)
NTB = NTB.copy()
NTB.dropna(inplace = True)
NTB = NTB.drop(['CAPAIAN NILAI UJIAN NASIONAL'],axis=1)
NTB = NTB.reset_index()
NTB = NTB.drop(['index'],axis=1)

NTT = NTT.drop(['NPSN'],axis=1)
NTT = NTT.copy()
NTT.dropna(inplace = True)
NTT = NTT.drop(['CAPAIAN NILAI UJIAN NASIONAL'],axis=1)
NTT = NTT.reset_index()
NTT = NTT.drop(['index'],axis=1)

papua = papua.drop(['NPSN'],axis=1)
papua = papua.copy()
papua.dropna(inplace = True)
papua = papua.drop(['CAPAIAN NILAI UJIAN NASIONAL'],axis=1)
papua = papua.reset_index()
papua = papua.drop(['index'],axis=1)

bengkulu = bengkulu.drop(['NPSN'],axis=1)
bengkulu  = bengkulu.copy()
bengkulu.dropna(inplace = True)
bengkulu = bengkulu.drop(['CAPAIAN NILAI UJIAN NASIONAL'],axis=1)
bengkulu = bengkulu.reset_index()
bengkulu = bengkulu.drop(['index'],axis=1)

malut = malut.drop(['NPSN'],axis=1)
malut  = malut.copy()
malut.dropna(inplace = True)
malut = malut.drop(['CAPAIAN NILAI UJIAN NASIONAL'],axis=1)
malut = malut.reset_index()
malut = malut.drop(['index'],axis=1)

bangkabel = bangkabel.drop(['NPSN'],axis=1)
bangkabel = bangkabel.copy()
bangkabel.dropna(inplace = True)
bangkabel = bangkabel.drop(['CAPAIAN NILAI UJIAN NASIONAL'],axis=1)
bangkabel = bangkabel.reset_index()
bangkabel = bangkabel.drop(['index'],axis=1)

goront = goront.drop(['NPSN'],axis=1)
goront = goront.copy()
goront.dropna(inplace = True)
goront = goront.drop(['CAPAIAN NILAI UJIAN NASIONAL'],axis=1)
goront = goront.reset_index()
goront = goront.drop(['index'],axis=1)

banten = banten.drop(['NPSN'],axis=1)
banten = banten.copy()
banten.dropna(inplace = True)
banten = banten.drop(['CAPAIAN NILAI UJIAN NASIONAL'],axis=1)
banten = banten.reset_index()
bantens = banten.drop(['index'],axis=1)

kepriau = kepriau.drop(['NPSN'],axis=1)
kepriau = kepriau.copy()
kepriau.dropna(inplace = True)
kepriau = kepriau.drop(['CAPAIAN NILAI UJIAN NASIONAL'],axis=1)
kepriau = kepriau.reset_index()
kepriau = kepriau.drop(['index'],axis=1)

sulbar = sulbar.drop(['NPSN'],axis=1)
sulbar = sulbar.copy()
sulbar.dropna(inplace = True)
sulbar = sulbar.drop(['CAPAIAN NILAI UJIAN NASIONAL'],axis=1)
sulbar = sulbar.reset_index()
sulbar = sulbar.drop(['index'],axis=1)

papbar = papbar.drop(['NPSN'],axis=1)
papbar = papbar.copy()
papbar.dropna(inplace = True)
papbar = papbar.drop(['CAPAIAN NILAI UJIAN NASIONAL'],axis=1)
papbar = papbar.reset_index()
papbar = papbar.drop(['index'],axis=1)

kalut = kalut.drop(['NPSN'],axis=1)
kalut = kalut.copy()
kalut.dropna(inplace = True)
kalut = kalut.drop(['CAPAIAN NILAI UJIAN NASIONAL'],axis=1)
kalut = kalut.reset_index()
kalut = kalut.drop(['index'],axis=1)

# %%
DKI.head()
# Out:
#         KODE          NAMA SATUAN PENDIDIKAN  ...    PKN RERATA NILAI
# 0   01010001    PKBM NEGERI 02 KARET TENGSIN  ...  39.36        33,68
# 1   01010002            PKBM 23 KEBON MELATI  ...  36.51        33,82
# 2   01010003              PKBM NURANI INSANI  ...  30.46        27,85
# 3   01010004                    PKBM VICKERY  ...     39        41,68
# 4   01010005  PKBM NUSANTARA BENDUNGAN HILIR  ...  39.14        35,38
#
# [5 rows x 12 columns]

# %%
sekolah= [DKI,jabar,jateng,DIY,jatim,aceh,sumut,sumbar,riau,jambi,sumsel,lampung,kalbar,kalteng,kalsel,kaltim,sulut,sulteng,sulsel,sultengg,maluku,bali,NTB,NTT,papua,bengkulu,malut,bangkabel,goront,banten,kepriau,sulbar,papbar,kalut]
Ck = pd.concat(sekolah)
Ck = Ck.reset_index()
Ck = Ck.drop(['index'],axis=1)
Ck.head(2)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:2: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#    level_0 BAHASA INDONESIA BAHASA INGGRIS  ... RERATA NILAI SOSIOLOGI STATUS
# 0        0            42.86          26.82  ...        33,68     42.73      T
# 1        1            41.59          28.03  ...        33,82     43.49      T
#
# [2 rows x 13 columns]

# %% [markdown]
# **2.Visualisasi**

# %% [markdown]
# **5 Sekolah dengan nilai terbaik Paket C IPA**

# %%
fig,axes = plt.subplots(7)
plt.subplots_adjust(wspace=0.75, hspace=0.3)
fig.set_size_inches(5, 20)
print('5 sekolah dengan Rata-Rata Nilai UN Tertinggi untuk Setiap Mata Pelajaran')
sns.barplot(x='MATEMATIKA', y='NAMA SATUAN PENDIDIKAN', data=Ck.sort_values('MATEMATIKA',ascending = False).head(5),ax=axes[0],palette="cool")
sns.barplot(x='EKONOMI', y='NAMA SATUAN PENDIDIKAN', data=Ck.sort_values('EKONOMI',ascending = False).head(5),ax=axes[1],palette="cool")
sns.barplot(x='GEOGRAFI', y='NAMA SATUAN PENDIDIKAN', data=Ck.sort_values('GEOGRAFI',ascending = False).head(5),ax=axes[2],palette="cool")
sns.barplot(x='PKN', y='NAMA SATUAN PENDIDIKAN', data=Ck.sort_values('PKN',ascending = False).head(5),ax=axes[3],palette="cool")
sns.barplot(x='SOSIOLOGI', y='NAMA SATUAN PENDIDIKAN', data=Ck.sort_values('SOSIOLOGI',ascending = False).head(5),ax=axes[4],palette="cool")
sns.barplot(x='BAHASA INGGRIS', y='NAMA SATUAN PENDIDIKAN', data=Ck.sort_values('BAHASA INGGRIS',ascending = False).head(5),ax=axes[5],palette="cool")
sns.barplot(x='BAHASA INDONESIA', y='NAMA SATUAN PENDIDIKAN', data=Ck.sort_values('BAHASA INDONESIA',ascending = False).head(5),ax=axes[6],palette="cool")
# Out:
# 5 sekolah dengan Rata-Rata Nilai UN Tertinggi untuk Setiap Mata Pelajaran

# %% [markdown]
# **Perolehan 5 nilai rata-rata UN tertinggi dan terendah Paket C IPA Tingkat Sekolah**

# %%
Ck1=Ck.copy()
Ck1 = Ck1.stack().str.replace(',','.').unstack()
Ck1[['RERATA NILAI']] = Ck1[['RERATA NILAI']].apply(pd.to_numeric)
plt.figure(figsize=(6,4))
sns.barplot(x='RERATA NILAI', y='NAMA SATUAN PENDIDIKAN', data=Ck1.sort_values('RERATA NILAI',ascending = False).head(5),palette="cool")
